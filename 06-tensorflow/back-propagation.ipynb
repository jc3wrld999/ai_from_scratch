# %% [markdown]
# ## 역전파
#
# 역전파(Back propagation)는 다층 퍼셉트론 모델을 이루는 가중치들을 개선하기 위해 개발된 여러 알고리즘들 중 가장 유명하고 널리 쓰이는 방법이다. 퍼셉트론 한 개의 가중치들을 개선시키는 역전파를 구현해 보자.
#
# ![image.png](attachment:image.png)
#
# - 입력은 $x1,x2,x3$세 개의 정수로 주어지고, 각각 $w1$,$w2$,$w3$의 계수가 곱해져 sigmoid 함수를 통과할 값은 $x1w1+x2w2+x3w3x$가 된다.
# - 여기서 $w1,w2,w3$가 바로 우리가 이번 실습에서 알아내야 하는 가중치입니다.
# - $x1w1+x2w2+x3w3x$가 sigmoid 함수를 거치고 나면 0 ~ 1 사이의 값으로 변환됩니다. 이는 특정 클래스로 분류될 확률을 나타내며, 0.5보다 작을 경우 0으로, 0.5보다 클 경우 1로 분류된다고 합시다.
# - 이제 이 퍼셉트론을 학습시키려고 합니다. 좀 더 정확히 이야기하면,  $w1,w2,w3$와 그 클래스 $y$가 여러 개 주어질 때, $y$값을 가장 잘 예측하는  $w1,w2,w3$를 찾아야 합니다.
#
# 찾는방법
# - 우선 가중치 $w$들을 초기화하고, 이를 여러 번의 학습을 거쳐 알아내야 합니다.
# - 손실 함수(loss function)의 gradient 값을 역전파해서 받은 후, 그 값을 참고하여 손실 함수값을 최소화 하는 방향으로 $w1,w2,w3$를 업데이트
