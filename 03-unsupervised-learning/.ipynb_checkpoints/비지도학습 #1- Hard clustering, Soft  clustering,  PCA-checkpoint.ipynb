# %% [markdown]
# ##
# - 비슷한 포인트들은 서로 뭉쳐있다. > 하드 클러스터링
# ![image.png](attachment:image.png)
#     - 60%는 고양이 40%는 강아지 이런 경우는 없음
#     - Hierarachical Clustering, K-Means, DBSCAN, OPTICS
# - 한개의 데이터 포인트는 숨겨진 클러스터들의 집합이다. > 소프트 클러스터링
# ![image-2.png](attachment:image-2.png)
#     - 하드 클러스터링은 100%, 0%로 나뉘지만 소프트는 걸쳐있으면 60%, 40%이렇게 나뉨
#     - Topic Models, FCM, Gaussian Mixture Models(EM), Soft K-Means

# %% [markdown]
# ## PCA(주성분 분석)
#
# 1. 사용하는 이유
# - 고차원의 데이터를 저차원으로 줄이기 위해
# - 데이터 정제화를 위해

# %% [markdown]
# ## PCA 차원축소
#
#
# 주성분 분석(Principal Component Analysis, PCA)은 고차원 데이터를 저차원의 데이터로 변환하는 알고리즘입니다. 데이터를 한 개의 축으로 투사했을 때 분산이 가장 높아지도록 데이터를 조정합니다.
#
# 13차원의 와인 데이터셋을 2차원으로 변환해보겠습니다.
#
# ### `sklearn.decomposition.PCA`
#
# PCA를 사용하기 위하여 scikit-learn에 구현된 함수를 호출합니다. `PCA()` 함수를 쉽게 PCA를 적용할 수 있습니다.
#
# 다음은 13차원의 데이터 `X`를 2차원으로 줄이는 코드입니다. 이때 `X`의 `shape`은 (n, 13) 형식이 되어야 합니다.
# ```
# pca = sklearn.decomposition.PCA(n_components=2)
# pca.fit(X)
# pca_array = pca.transform(X)
# ```
#
# 실습에 사용된 와인 데이터는 [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)의 [Wine Data Set](https://archive.ics.uci.edu/ml/datasets/Wine)에서 받을 수 있습니다.

# %% [markdown]
# ## PCA 차원축소
#
# #### [⏩ 영상 바로가기](#video-00:00:00-00:36:31)
#
# 주성분 분석(Principal Component Analysis, PCA)은 고차원 데이터를 저차원의 데이터로 변환하는 알고리즘입니다. 데이터를 한 개의 축으로 투사했을 때 분산이 가장 높아지도록 데이터를 조정합니다.
#
# 13차원의 와인 데이터셋을 2차원으로 변환해보겠습니다.
#
# ### `sklearn.decomposition.PCA`
#
# PCA를 사용하기 위하여 scikit-learn에 구현된 함수를 호출합니다. `PCA()` 함수를 쉽게 PCA를 적용할 수 있습니다.
#
# 다음은 13차원의 데이터 `X`를 2차원으로 줄이는 코드입니다. 이때 `X`의 `shape`은 (n, 13) 형식이 되어야 합니다.
# ```
# pca = sklearn.decomposition.PCA(n_components=2)
# pca.fit(X)
# pca_array = pca.transform(X)
# ```
#
# 실습에 사용된 와인 데이터는 [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/index.php)의 [Wine Data Set](https://archive.ics.uci.edu/ml/datasets/Wine)에서 받을 수 있습니다.
# ## 과제
#
# 이번 과제에서는 와인 데이터를 입력받아 PCA를 통해 2차원으로 줄인 뒤, 이것을 matplotlib을 이용해 출력하는 연습을 해 보겠습니다.
#
# `data/wine.csv`에 와인 데이터가 준비되어 있습니다. 각 행과 열은 각각 와인과 와인의 특성을 나타냅니다.

# %%
import sklearn.decomposition
import matplotlib.pyplot as plt
import numpy as np
import csv

def main():
    X, attributes = input_data()
    print(X, '\n')
    print(X.shape, '\n') # (178, 13)
    # 정규화
    pca_array = normalize(X)
    # 차원축소
    pca, pca_array = run_PCA(X, 2)
    print(pca, '\n')
    print(pca_array, '\n')
    visualize_2d_wine(pca_array)

def input_data():
    X = []
    attributes = []
    with open('attributes.txt') as f:
        attributes = f.readlines()
    attributes = [x.strip() for x in attributes]

    csvreader = csv.reader(open('data_wine.csv'))
    for line in csvreader:
        float_num = [float(x) for x in line]
        X.append(float_num)
    return np.array(X), attributes

def run_PCA(X, num_components):
    '''
    차원축소
    [1.423e+01 1.710e+00 2.430e+00 ... 1.040e+00 3.920e+00 1.065e+03] > [-5.00662308e-01  1.34687825e-01]
    '''
    pca = sklearn.decomposition.PCA(n_components=num_components)
    pca.fit(X)
    pca_array = pca.transform(X)
    return pca, pca_array
    
def normalize(X):
    '''
    각각의 feature에 대해,
    178개의 데이터에 나타나는 해당하는 feature의 값이 최소 0, 최대 1이 되도록
    선형적으로 데이터를 이동시킵니다.
    3, 4, 5 >> 0, 1 사이 값으로
    min: 3 max: 5
    0 < (3-3)/5  < 1 왜냐면 분자는 무조건 0보다 크거나 작고 분모는 무조건 분자보다 크기 때문
    '''
    for i in range(X.shape[1]):
        X[:, i] = (X[:, i] - np.min(X[:, i])) / np.max(X[:, i])
    return X

def visualize_2d_wine(X):
    '''X를 시각화하는 코드를 구현합니다.'''
    plt.scatter(X[:, 0], X[:, 1])
    plt.show()
    plt.savefig("image.png")
    

if __name__ == '__main__':
    main()
# Out:
# [[1.423e+01 1.710e+00 2.430e+00 ... 1.040e+00 3.920e+00 1.065e+03]
#  [1.320e+01 1.780e+00 2.140e+00 ... 1.050e+00 3.400e+00 1.050e+03]
#  [1.316e+01 2.360e+00 2.670e+00 ... 1.030e+00 3.170e+00 1.185e+03]
#  ...
#  [1.327e+01 4.280e+00 2.260e+00 ... 5.900e-01 1.560e+00 8.350e+02]
#  [1.317e+01 2.590e+00 2.370e+00 ... 6.000e-01 1.620e+00 8.400e+02]
#  [1.413e+01 4.100e+00 2.740e+00 ... 6.100e-01 1.600e+00 5.600e+02]]
#
# (178, 13)
#
# PCA(n_components=2)
#
# [[-5.00662308e-01  1.34687825e-01]
#  [-3.48097608e-01  1.02096273e-02]
#  [-4.34528244e-01  2.25163551e-01]
#  [-6.09955053e-01  4.59990745e-01]
#  [-1.52154358e-01  1.21196352e-02]
#  [-4.62744248e-01  3.53901132e-01]
#  [-3.74528466e-01  1.60044532e-01]
#  [-3.07408246e-01  1.57333090e-01]
#  [-3.62001721e-01  1.03537904e-01]
#  [-4.66860543e-01  1.70161905e-01]
#  [-5.63451061e-01  2.84452286e-01]
#  [-2.77106608e-01  9.92326653e-02]
#  [-3.46066902e-01  1.73978838e-01]
#  [-4.87169821e-01  1.80621475e-01]
# ...

# %% [markdown]
# ## Reference
# - [](https://archive.ics.uci.edu/ml/index.php)
# - [wine dataset](https://archive.ics.uci.edu/ml/datasets/Wine)
